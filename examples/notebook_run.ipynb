# %% [markdown]
# Setup

# %%
import time
import argparse
import json
import csv

from qiskit import QuantumCircuit
from qiskit.transpiler import CouplingMap, PassManager
from pathlib import Path
from typing import Dict, List, Iterable
from util import EAGLE_COUPLING, sabre, count_swaps 
from multilevel_sabre import MultiLevelSabre

# %% [markdown]
# Coupling map

# %%
from util import EAGLE_COUPLING

coupling_map = CouplingMap(couplinglist=EAGLE_COUPLING)
coupling_map.make_symmetric()
#coupling_map.draw()

# %% [markdown]
# Select circuits

# %%
directory = "circuits/"
circuit_files = []
for file in Path(directory).glob("*.qasm"):
    circuit_files.append(file)
print(f"Found {len(circuit_files)} circuit files.")
# Out:
# Found 12 circuit files.

# %% [markdown]
# Run circuits through Sabre and Multi-Level Sabre

# %%
def run_comparison_example(qasm_path: Path) -> Dict:
    circuit = QuantumCircuit.from_qasm_file(qasm_path)

    # Run SABRE
    print("\nRunning SABRE...")
    start_time = time.time()
    sabre_swaps, sabre_circuit = sabre(
        circuit=circuit,
        coupling=EAGLE_COUPLING,
        random_seed=1
    )
    sabre_time = time.time() - start_time
    sabre_ops = sabre_circuit.count_ops()

    # Run MultiLevel SABRE
    print("\nRunning MultiLevel SABRE...")
    start_time = time.time()
    multilevel_pass = PassManager([
        MultiLevelSabre(
            coupling_graph=coupling_map,
            cycles=10,
            random_seed=1,
            coarsest_solving_trials=50,
            num_interpolation=10,
            use_initial_embedding=True,
            verbose=0
        )
    ])

    multilevel_circuit = multilevel_pass.run(circuit)
    multilevel_time = time.time() - start_time
    multilevel_ops = multilevel_circuit.count_ops()
    multilevel_swaps = count_swaps(multilevel_circuit)

    # Prepare metrics row (keep ops as JSON strings for CSV-friendliness)
    row = {
        "qasm_file": str(qasm_path),
        "sabre_swaps": sabre_swaps,
        "sabre_time_s": round(sabre_time, 4),
        "sabre_depth": sabre_circuit.depth(),
        "sabre_2q_depth": sabre_circuit.depth(lambda x: x.operation.num_qubits == 2),
        "sabre_size": sabre_circuit.size(),
        "sabre_ops_json": json.dumps(sabre_ops, default=int),

        "multilevel_swaps": multilevel_swaps,
        "multilevel_time_s": round(multilevel_time, 4),
        "multilevel_depth": multilevel_circuit.depth(),
        "multilevel_2q_depth": multilevel_circuit.depth(lambda x: x.operation.num_qubits == 2),
        "multilevel_size": multilevel_circuit.size(),
        "multilevel_ops_json": json.dumps(multilevel_ops, default=int),
    }

    # Derived metrics
    row["speedup"] = round(row["sabre_time_s"] / row["multilevel_time_s"], 4) if row["multilevel_time_s"] > 0 else float("inf")
    row["swap_reduction_pct"] = round(((row["sabre_swaps"] - row["multilevel_swaps"]) / row["sabre_swaps"] * 100), 3) if row["sabre_swaps"] else 0.0

    # Pretty print to terminal
    print("\nComparison Results:")
    print("SABRE:")
    print(f"  - Number of SWAPs: {row['sabre_swaps']}")
    print(f"  - Compilation time: {row['sabre_time_s']:.2f} seconds")
    print(f"  - Circuit depth: {row['sabre_depth']}")
    print(f"  - Circuit 2Q depth: {row['sabre_2q_depth']}")
    print(f"  - Circuit size: {row['sabre_size']}")
    print("\nMultiLevel SABRE:")
    print(f"  - Number of SWAPs: {row['multilevel_swaps']}")
    print(f"  - Compilation time: {row['multilevel_time_s']:.2f} seconds")
    print(f"  - Circuit depth: {row['multilevel_depth']}")
    print(f"  - Circuit 2Q depth: {row['multilevel_2q_depth']}")
    print(f"  - Circuit size: {row['multilevel_size']}")
    print(f"\nSpeedup: {row['speedup']:.2f}x")
    print(f"SWAP reduction: {row['swap_reduction_pct']:.1f}%")
    
    return row

# %%
rows = []
for qasm_file in circuit_files:
    rows.append(run_comparison_example(qasm_file))
# Out:
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 24
#   - Compilation time: 0.12 seconds
#   - Circuit depth: 259
#   - Circuit 2Q depth: 161
#   - Circuit size: 611
#
# MultiLevel SABRE:
#   - Number of SWAPs: 17
#   - Compilation time: 0.77 seconds
#   - Circuit depth: 254
#   - Circuit 2Q depth: 153
#   - Circuit size: 604
#
# Speedup: 0.15x
# SWAP reduction: 29.2%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.02 seconds
#   - Circuit depth: 44
#   - Circuit 2Q depth: 0
#   - Circuit size: 126
#
# MultiLevel SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.03 seconds
#   - Circuit depth: 44
#   - Circuit 2Q depth: 0
#   - Circuit size: 126
#
# Speedup: 0.66x
# SWAP reduction: 0.0%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.02 seconds
#   - Circuit depth: 36
#   - Circuit 2Q depth: 0
#   - Circuit size: 102
#
# MultiLevel SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.01 seconds
#   - Circuit depth: 36
#   - Circuit 2Q depth: 0
#   - Circuit size: 102
#
# Speedup: 3.00x
# SWAP reduction: 0.0%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 6
#   - Compilation time: 0.06 seconds
#   - Circuit depth: 70
#   - Circuit 2Q depth: 65
#   - Circuit size: 230
#
# MultiLevel SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.06 seconds
#   - Circuit depth: 58
#   - Circuit 2Q depth: 52
#   - Circuit size: 274
#
# Speedup: 1.03x
# SWAP reduction: 100.0%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
# [4, 3, 2, 1, 0, 14, 18, 19, 20, 33, 39, 40, 41, 53, 60, 61, 62, 63, 64, 65, 66, 73, 85, 86, 87]
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 37
#   - Compilation time: 0.03 seconds
#   - Circuit depth: 64
#   - Circuit 2Q depth: 61
#   - Circuit size: 281
#
# MultiLevel SABRE:
#   - Number of SWAPs: 33
#   - Compilation time: 0.68 seconds
#   - Circuit depth: 64
#   - Circuit 2Q depth: 60
#   - Circuit size: 278
#
# Speedup: 0.04x
# SWAP reduction: 10.8%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
# [7, 8, 16, 26, 25, 24, 34, 23, 22, 15, 4, 3, 2, 1, 0, 14, 18, 19, 20, 33, 39, 38, 40, 41, 53, 60, 61, 62, 63, 64, 65, 66, 67, 68, 55, 49, 48, 47, 35, 28, 29, 30, 17, 12, 11]
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 1441
#   - Compilation time: 0.31 seconds
#   - Circuit depth: 1438
#   - Circuit 2Q depth: 918
#   - Circuit size: 5657
#
# MultiLevel SABRE:
#   - Number of SWAPs: 2548
#   - Compilation time: 11.60 seconds
#   - Circuit depth: 1672
#   - Circuit 2Q depth: 1034
#   - Circuit size: 12439
#
# Speedup: 0.03x
# SWAP reduction: -76.8%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 16
#   - Compilation time: 0.03 seconds
#   - Circuit depth: 95
#   - Circuit 2Q depth: 93
#   - Circuit size: 172
#
# MultiLevel SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.06 seconds
#   - Circuit depth: 79
#   - Circuit 2Q depth: 77
#   - Circuit size: 156
#
# Speedup: 0.55x
# SWAP reduction: 100.0%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 17
#   - Compilation time: 0.06 seconds
#   - Circuit depth: 18
#   - Circuit 2Q depth: 10
#   - Circuit size: 552
#
# MultiLevel SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.06 seconds
#   - Circuit depth: 16
#   - Circuit 2Q depth: 4
#   - Circuit size: 1170
#
# Speedup: 0.91x
# SWAP reduction: 100.0%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 214
#   - Compilation time: 0.08 seconds
#   - Circuit depth: 247
#   - Circuit 2Q depth: 176
#   - Circuit size: 710
#
# MultiLevel SABRE:
#   - Number of SWAPs: 106
#   - Compilation time: 1.22 seconds
#   - Circuit depth: 197
#   - Circuit 2Q depth: 134
#   - Circuit size: 602
#
# Speedup: 0.06x
# SWAP reduction: 50.5%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 14
#   - Compilation time: 0.12 seconds
#   - Circuit depth: 86
#   - Circuit 2Q depth: 76
#   - Circuit size: 292
#
# MultiLevel SABRE:
#   - Number of SWAPs: 14
#   - Compilation time: 0.76 seconds
#   - Circuit depth: 90
#   - Circuit 2Q depth: 76
#   - Circuit size: 292
#
# Speedup: 0.15x
# SWAP reduction: 0.0%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.03 seconds
#   - Circuit depth: 462
#   - Circuit 2Q depth: 234
#   - Circuit size: 698
#
# MultiLevel SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.01 seconds
#   - Circuit depth: 462
#   - Circuit 2Q depth: 234
#   - Circuit size: 698
#
# Speedup: 2.91x
# SWAP reduction: 0.0%
#
# Running SABRE...
#
# Running MultiLevel SABRE...
#
# Comparison Results:
# SABRE:
#   - Number of SWAPs: 14
#   - Compilation time: 0.03 seconds
#   - Circuit depth: 80
#   - Circuit 2Q depth: 78
#   - Circuit size: 144
#
# MultiLevel SABRE:
#   - Number of SWAPs: 0
#   - Compilation time: 0.12 seconds
#   - Circuit depth: 66
#   - Circuit 2Q depth: 64
#   - Circuit size: 130
#
# Speedup: 0.24x
# SWAP reduction: 100.0%

# %% [markdown]
# Select filepath for results to be saved

# %%
def write_csv(rows: List[Dict], out_csv: Path) -> None:
    if not rows:
        print("No rows to write.")
        return
    fieldnames = [
        "qasm_file",
        "sabre_swaps", "sabre_time_s", "sabre_depth", "sabre_2q_depth", "sabre_size", "sabre_ops_json",
        "multilevel_swaps", "multilevel_time_s", "multilevel_depth", "multilevel_2q_depth", "multilevel_size", "multilevel_ops_json",
        "speedup", "swap_reduction_pct",
        "error",
    ]
    out_csv.parent.mkdir(parents=True, exist_ok=True)
    with out_csv.open("w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for r in rows:
            writer.writerow({k: r.get(k, "") for k in fieldnames})
    print(f"\nWrote CSV: {out_csv}")

result_path = Path("results/comparison_test.csv")

# Save results to CSV
write_csv(rows, result_path)
# Out:
# Wrote CSV: results/comparison_test.csv

# %%
rows
# Out:
# [{'qasm_file': 'circuits/wstate_n118.qasm',
#   'sabre_swaps': 24,
#   'sabre_time_s': 0.1172,
#   'sabre_depth': 259,
#   'sabre_2q_depth': 161,
#   'sabre_size': 611,
#   'sabre_ops_json': '{"ry": 234, "measure": 118, "cz": 117, "cx": 117, "swap": 24, "x": 1, "barrier": 1}',
#   'multilevel_swaps': 17,
#   'multilevel_time_s': 0.7724,
#   'multilevel_depth': 254,
#   'multilevel_2q_depth': 153,
#   'multilevel_size': 604,
#   'multilevel_ops_json': '{"ry": 234, "measure": 118, "cz": 117, "cx": 117, "swap": 17, "x": 1, "barrier": 1}',
#   'speedup': 0.1517,
#   'swap_reduction_pct': 29.167},
#  {'qasm_file': 'circuits/swap_test_n83.qasm',
#   'sabre_swaps': 0,
#   'sabre_time_s': 0.0171,
#   'sabre_depth': 44,
#   'sabre_2q_depth': 0,
#   'sabre_size': 126,
#   'sabre_ops_json': '{"rx": 82, "cswap": 41, "h": 2, "measure": 1}',
#   'multilevel_swaps': 0,
#   'multilevel_time_s': 0.026,
#   'multilevel_depth': 44,
#   'multilevel_2q_depth': 0,
#   'multilevel_size': 126,
#   'multilevel_ops_json': '{"rx": 82, "cswap": 41, "h": 2, "measure": 1}',
#   'speedup': 0.6577,
#   'swap_reduction_pct': 0.0},
#  {'qasm_file': 'circuits/knn_67.qasm',
#   'sabre_swaps': 0,
#   'sabre_time_s': 0.0189,
#   'sabre_depth': 36,
#   'sabre_2q_depth': 0,
#   'sabre_size': 102,
#   'sabre_ops_json': '{"ry": 66, "cswap": 33, "h": 2, "measure": 1}',
#   'multilevel_swaps': 0,
#   'multilevel_time_s': 0.0063,
#   'multilevel_depth': 36,
#   'multilevel_2q_depth': 0,
#   'multilevel_size': 102,
#   'multilevel_ops_json': '{"ry": 66, "cswap": 33, "h": 2, "measure": 1}',
#   'speedup': 3.0,
#   'swap_reduction_pct': 0.0},
#  {'qasm_file': 'circuits/dnn_n51.qasm',
#   'sabre_swaps': 6,
#   'sabre_time_s': 0.0621,
#   'sabre_depth': 70,
#   'sabre_2q_depth': 65,
#   'sabre_size': 230,
#   'sabre_ops_json': '{"measure": 51, "u3": 50, "cswap": 25, "rzz": 24, "cry": 24, "crz": 24, "swap": 6, "h": 2, "ryy": 1, "ryy_140578989711904": 1, "ryy_140578989712096": 1, "ryy_140578989712192": 1, "ryy_140578989712288": 1, "ryy_140578989712384": 1, "ryy_140578989712480": 1, "ryy_140578989712576": 1, "ryy_140578989712672": 1, "ryy_140578989712768": 1, "ryy_140578989712864": 1, "ryy_140578989712960": 1, "ryy_140578989713056": 1, "ryy_140578989713152": 1, "ryy_140578989713248": 1, "ryy_140578989713344": 1, "ryy_140578989713440": 1, "ryy_140578989713536": 1, "ryy_140578989713632": 1, "ryy_140578989713728": 1, "ryy_140578989713824": 1, "ryy_140578989713920": 1, "ryy_140578989714016": 1, "ryy_140578989714112": 1, "barrier": 1}',
#   'multilevel_swaps': 0,
#   'multilevel_time_s': 0.0603,
#   'multilevel_depth': 58,
#   'multilevel_2q_depth': 52,
#   'multilevel_size': 274,
#   'multilevel_ops_json': '{"measure": 51, "ry": 50, "rz": 50, "cswap": 25, "rzz": 24, "cry": 24, "crz": 24, "h": 2, "ryy": 1, "ryy_140578989711904": 1, "ryy_140578989712096": 1, "ryy_140578989712192": 1, "ryy_140578989712288": 1, "ryy_140578989712384": 1, "ryy_140578989712480": 1, "ryy_140578989712576": 1, "ryy_140578989712672": 1, "ryy_140578989712768": 1, "ryy_140578989712864": 1, "ryy_140578989712960": 1, "ryy_140578989713056": 1, "ryy_140578989713152": 1, "ryy_140578989713248": 1, "ryy_140578989713344": 1, "ryy_140578989713440": 1, "ryy_140578989713536": 1, "ryy_140578989713632": 1, "ryy_140578989713728": 1, "ryy_140578989713824": 1, "ryy_140578989713920": 1, "ryy_140578989714016": 1, "ryy_140578989714112": 1, "barrier": 1}',
#   'speedup': 1.0299,
#   'swap_reduction_pct': 100.0},
#  {'qasm_file': 'circuits/bv_n70.qasm',
#   'sabre_swaps': 37,
#   'sabre_time_s': 0.0269,
#   'sabre_depth': 64,
#   'sabre_2q_depth': 61,
#   'sabre_size': 281,
#   'sabre_ops_json': '{"h": 138, "measure": 69, "swap": 37, "cx": 36, "barrier": 2, "u2": 1}',
#   'multilevel_swaps': 33,
#   'multilevel_time_s': 0.6826,
#   'multilevel_depth': 64,
#   'multilevel_2q_depth': 60,
#   'multilevel_size': 278,
#   'multilevel_ops_json': '{"h": 139, "measure": 69, "cx": 36, "swap": 33, "barrier": 2, "x": 1}',
#   'speedup': 0.0394,
#   'swap_reduction_pct': 10.811},
#  {'qasm_file': 'circuits/qft_n63.qasm',
#   'sabre_swaps': 1441,
#   'sabre_time_s': 0.3112,
#   'sabre_depth': 1438,
#   'sabre_2q_depth': 918,
#   'sabre_size': 5657,
#   'sabre_ops_json': '{"u1": 2076, "cx": 2014, "swap": 1441, "h": 63, "measure": 63, "barrier": 1}',
#   'multilevel_swaps': 2548,
#   'multilevel_time_s': 11.6004,
#   'multilevel_depth': 1672,
#   'multilevel_2q_depth': 1034,
#   'multilevel_size': 12439,
#   'multilevel_ops_json': '{"u1": 5859, "cx": 3906, "swap": 2548, "h": 63, "measure": 63, "barrier": 1}',
#   'speedup': 0.0268,
#   'swap_reduction_pct': -76.822},
#  {'qasm_file': 'circuits/ghz_n78.qasm',
#   'sabre_swaps': 16,
#   'sabre_time_s': 0.032,
#   'sabre_depth': 95,
#   'sabre_2q_depth': 93,
#   'sabre_size': 172,
#   'sabre_ops_json': '{"measure": 78, "cx": 77, "swap": 16, "h": 1, "barrier": 1}',
#   'multilevel_swaps': 0,
#   'multilevel_time_s': 0.0587,
#   'multilevel_depth': 79,
#   'multilevel_2q_depth': 77,
#   'multilevel_size': 156,
#   'multilevel_ops_json': '{"measure": 78, "cx": 77, "h": 1, "barrier": 1}',
#   'speedup': 0.5451,
#   'swap_reduction_pct': 100.0},
#  {'qasm_file': 'circuits/ising_n98.qasm',
#   'sabre_swaps': 17,
#   'sabre_time_s': 0.056,
#   'sabre_depth': 18,
#   'sabre_2q_depth': 10,
#   'sabre_size': 552,
#   'sabre_ops_json': '{"cx": 194, "rz": 145, "u2": 98, "measure": 98, "swap": 17, "barrier": 1}',
#   'multilevel_swaps': 0,
#   'multilevel_time_s': 0.0617,
#   'multilevel_depth': 16,
#   'multilevel_2q_depth': 4,
#   'multilevel_size': 1170,
#   'multilevel_ops_json': '{"rz": 584, "h": 294, "cx": 194, "measure": 98, "barrier": 1}',
#   'speedup': 0.9076,
#   'swap_reduction_pct': 100.0},
#  {'qasm_file': 'circuits/adder_n118.qasm',
#   'sabre_swaps': 214,
#   'sabre_time_s': 0.0791,
#   'sabre_depth': 247,
#   'sabre_2q_depth': 176,
#   'sabre_size': 710,
